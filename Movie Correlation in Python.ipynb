# %%
# Import libraries

import pandas as pd
import seaborn as sns
import numpy as np

import matplotlib
import matplotlib.pyplot as plt
plt.style.use('ggplot')
from matplotlib.pyplot import figure

# %matplotlib inline 
matplotlib.rcParams['figure.figsize'] = (12,8) #Adjusts the configuration of the plots we will create. 

#Read in the data

df = pd.read_csv(r'C:\Users\Faisal\Data Analyst_ALL\Tableau\Portfolio\Projects\Project 11 - Python\movies.csv')

# %%
# Lets look at the data
df.head()
# Out:
#                                              name rating      genre  year  \
# 0                                     The Shining      R      Drama  1980
# 1                                 The Blue Lagoon      R  Adventure  1980
# 2  Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# 3                                       Airplane!     PG     Comedy  1980
# 4                                      Caddyshack      R     Comedy  1980
#
#                         released  score      votes         director  \
# 0  June 13, 1980 (United States)    8.4   927000.0  Stanley Kubrick
# 1   July 2, 1980 (United States)    5.8    65000.0   Randal Kleiser
# 2  June 20, 1980 (United States)    8.7  1200000.0   Irvin Kershner
# 3   July 2, 1980 (United States)    7.7   221000.0     Jim Abrahams
# 4  July 25, 1980 (United States)    7.3   108000.0     Harold Ramis
#
#                     writer            star         country    budget  \
# 0             Stephen King  Jack Nicholson  United Kingdom  19000000
# 1  Henry De Vere Stacpoole  Brooke Shields   United States   4500000
# 2           Leigh Brackett     Mark Hamill   United States  18000000
# 3             Jim Abrahams     Robert Hays   United States   3500000
# 4       Brian Doyle-Murray     Chevy Chase   United States   6000000
#
#        gross             company  runtime
# 0   46998772        Warner Bros.    146.0
# 1   58853106   Columbia Pictures    104.0
# 2  538375067           Lucasfilm    124.0
# 3   83453539  Paramount Pictures     88.0
# 4   39846344      Orion Pictures     98.0

# %%
# Lets see if there is any missing data

for col in df.columns:
    pct_missing = np.mean(df[col].isnull())
    print('{} -  {}%'.format(col, pct_missing))
# Out:
# name -  0.0%
# rating -  0.010041731872717789%
# genre -  0.0%
# year -  0.0%
# released -  0.0002608242044861763%
# score -  0.0003912363067292645%
# votes -  0.0003912363067292645%
# director -  0.0%
# writer -  0.0003912363067292645%
# star -  0.00013041210224308815%
# country -  0.0003912363067292645%
# budget -  0.0%
# gross -  0.0%
# company -  0.002217005738132499%
# runtime -  0.0005216484089723526%

# %%
# Data types for our columns 
df.dtypes
# Out:
# name         object
# rating       object
# genre        object
# year          int64
# released     object
# score       float64
# votes       float64
# director     object
# writer       object
# star         object
# country      object
# budget        int64
# gross         int64
# company      object
# runtime     float64
# dtype: object

# %%
# Change data type of columns
df['budget'] = df['budget'].astype('int64')
df['gross'] = df['gross'].astype('int64')

# %%
df.head()
# Out:
#                                              name rating      genre  year  \
# 0                                     The Shining      R      Drama  1980
# 1                                 The Blue Lagoon      R  Adventure  1980
# 2  Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# 3                                       Airplane!     PG     Comedy  1980
# 4                                      Caddyshack      R     Comedy  1980
#
#     released  score      votes         director                   writer  \
# 0  13-Jun-80    8.4   927000.0  Stanley Kubrick             Stephen King
# 1   2-Jul-80    5.8    65000.0   Randal Kleiser  Henry De Vere Stacpoole
# 2  20-Jun-80    8.7  1200000.0   Irvin Kershner           Leigh Brackett
# 3   2-Jul-80    7.7   221000.0     Jim Abrahams             Jim Abrahams
# 4  25-Jul-80    7.3   108000.0     Harold Ramis       Brian Doyle-Murray
#
#              star         country    budget      gross             company  \
# 0  Jack Nicholson  United Kingdom  19000000   46998772        Warner Bros.
# 1  Brooke Shields   United States   4500000   58853106   Columbia Pictures
# 2     Mark Hamill   United States  18000000  538375067           Lucasfilm
# 3     Robert Hays   United States   3500000   83453539  Paramount Pictures
# 4     Chevy Chase   United States   6000000   39846344      Orion Pictures
#
#    runtime
# 0    146.0
# 1    104.0
# 2    124.0
# 3     88.0
# 4     98.0

# %%
df['yearcorrect'] = df['released'].astype(str).str.split().str[2]

df.head()
# Out:
#                                              name rating      genre  year  \
# 0                                     The Shining      R      Drama  1980
# 1                                 The Blue Lagoon      R  Adventure  1980
# 2  Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# 3                                       Airplane!     PG     Comedy  1980
# 4                                      Caddyshack      R     Comedy  1980
#
#     released  score      votes         director                   writer  \
# 0  13-Jun-80    8.4   927000.0  Stanley Kubrick             Stephen King
# 1   2-Jul-80    5.8    65000.0   Randal Kleiser  Henry De Vere Stacpoole
# 2  20-Jun-80    8.7  1200000.0   Irvin Kershner           Leigh Brackett
# 3   2-Jul-80    7.7   221000.0     Jim Abrahams             Jim Abrahams
# 4  25-Jul-80    7.3   108000.0     Harold Ramis       Brian Doyle-Murray
#
#              star         country    budget      gross             company  \
# 0  Jack Nicholson  United Kingdom  19000000   46998772        Warner Bros.
# 1  Brooke Shields   United States   4500000   58853106   Columbia Pictures
# 2     Mark Hamill   United States  18000000  538375067           Lucasfilm
# 3     Robert Hays   United States   3500000   83453539  Paramount Pictures
# 4     Chevy Chase   United States   6000000   39846344      Orion Pictures
#
#    runtime  yearcorrect
# 0    146.0          NaN
# 1    104.0          NaN
# 2    124.0          NaN
# 3     88.0          NaN
# 4     98.0          NaN

# %%
df.sort_values(by=['gross'], inplace = False, ascending=False)
df.head()
# Out:
#                                              name rating      genre  year  \
# 0                                     The Shining      R      Drama  1980
# 1                                 The Blue Lagoon      R  Adventure  1980
# 2  Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# 3                                       Airplane!     PG     Comedy  1980
# 4                                      Caddyshack      R     Comedy  1980
#
#     released  score      votes         director                   writer  \
# 0  13-Jun-80    8.4   927000.0  Stanley Kubrick             Stephen King
# 1   2-Jul-80    5.8    65000.0   Randal Kleiser  Henry De Vere Stacpoole
# 2  20-Jun-80    8.7  1200000.0   Irvin Kershner           Leigh Brackett
# 3   2-Jul-80    7.7   221000.0     Jim Abrahams             Jim Abrahams
# 4  25-Jul-80    7.3   108000.0     Harold Ramis       Brian Doyle-Murray
#
#              star         country    budget      gross             company  \
# 0  Jack Nicholson  United Kingdom  19000000   46998772        Warner Bros.
# 1  Brooke Shields   United States   4500000   58853106   Columbia Pictures
# 2     Mark Hamill   United States  18000000  538375067           Lucasfilm
# 3     Robert Hays   United States   3500000   83453539  Paramount Pictures
# 4     Chevy Chase   United States   6000000   39846344      Orion Pictures
#
#    runtime  yearcorrect
# 0    146.0          NaN
# 1    104.0          NaN
# 2    124.0          NaN
# 3     88.0          NaN
# 4     98.0          NaN

# %%
pd.set_option('display.max_rows', None)

# %%
#Drop any duplicates
df.drop_duplicates()
df.head()
# Out:
#                                              name rating      genre  year  \
# 0                                     The Shining      R      Drama  1980
# 1                                 The Blue Lagoon      R  Adventure  1980
# 2  Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# 3                                       Airplane!     PG     Comedy  1980
# 4                                      Caddyshack      R     Comedy  1980
#
#     released  score      votes         director                   writer  \
# 0  13-Jun-80    8.4   927000.0  Stanley Kubrick             Stephen King
# 1   2-Jul-80    5.8    65000.0   Randal Kleiser  Henry De Vere Stacpoole
# 2  20-Jun-80    8.7  1200000.0   Irvin Kershner           Leigh Brackett
# 3   2-Jul-80    7.7   221000.0     Jim Abrahams             Jim Abrahams
# 4  25-Jul-80    7.3   108000.0     Harold Ramis       Brian Doyle-Murray
#
#              star         country    budget      gross             company  \
# 0  Jack Nicholson  United Kingdom  19000000   46998772        Warner Bros.
# 1  Brooke Shields   United States   4500000   58853106   Columbia Pictures
# 2     Mark Hamill   United States  18000000  538375067           Lucasfilm
# 3     Robert Hays   United States   3500000   83453539  Paramount Pictures
# 4     Chevy Chase   United States   6000000   39846344      Orion Pictures
#
#    runtime  yearcorrect
# 0    146.0          NaN
# 1    104.0          NaN
# 2    124.0          NaN
# 3     88.0          NaN
# 4     98.0          NaN

# %%
# Budget high correlation
# company high correlation

# %%
# Scatter plot with budget vs gross

plt.scatter(x=df['budget'], y=df['gross'])

plt.title('Budget vs Gross Earnings')

plt.xlabel('Gross Earnings')

plt.ylabel('Budget for film')

plt.show()

# %%
df.head()
# Out:
#                                              name rating      genre  year  \
# 0                                     The Shining      R      Drama  1980
# 1                                 The Blue Lagoon      R  Adventure  1980
# 2  Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# 3                                       Airplane!     PG     Comedy  1980
# 4                                      Caddyshack      R     Comedy  1980
#
#                         released  score      votes         director  \
# 0  June 13, 1980 (United States)    8.4   927000.0  Stanley Kubrick
# 1   July 2, 1980 (United States)    5.8    65000.0   Randal Kleiser
# 2  June 20, 1980 (United States)    8.7  1200000.0   Irvin Kershner
# 3   July 2, 1980 (United States)    7.7   221000.0     Jim Abrahams
# 4  July 25, 1980 (United States)    7.3   108000.0     Harold Ramis
#
#                     writer            star         country    budget  \
# 0             Stephen King  Jack Nicholson  United Kingdom  19000000
# 1  Henry De Vere Stacpoole  Brooke Shields   United States   4500000
# 2           Leigh Brackett     Mark Hamill   United States  18000000
# 3             Jim Abrahams     Robert Hays   United States   3500000
# 4       Brian Doyle-Murray     Chevy Chase   United States   6000000
#
#        gross             company  runtime
# 0   46998772        Warner Bros.    146.0
# 1   58853106   Columbia Pictures    104.0
# 2  538375067           Lucasfilm    124.0
# 3   83453539  Paramount Pictures     88.0
# 4   39846344      Orion Pictures     98.0

# %%
# plot budget vs gross using seaborn

sns.regplot(x='budget', y = 'gross', data = df, scatter_kws = {"color": "red"}, line_kws = {"color": "blue"})
# Out:
# <Axes: xlabel='budget', ylabel='gross'>

# %%
# lets start looking at correlations

# %%
df.corr(numeric_only=True)
# Out:
#              year     score     votes    budget     gross   runtime
# year     1.000000  0.097995  0.222945  0.309212  0.261900  0.120811
# score    0.097995  1.000000  0.409182  0.055665  0.186392  0.399451
# votes    0.222945  0.409182  1.000000  0.486862  0.632834  0.309212
# budget   0.309212  0.055665  0.486862  1.000000  0.750157  0.269510
# gross    0.261900  0.186392  0.632834  0.750157  1.000000  0.245235
# runtime  0.120811  0.399451  0.309212  0.269510  0.245235  1.000000

# %%
df.corr(numeric_only=True, method='pearson')
# Out:
#              year     score     votes    budget     gross   runtime
# year     1.000000  0.097995  0.222945  0.309212  0.261900  0.120811
# score    0.097995  1.000000  0.409182  0.055665  0.186392  0.399451
# votes    0.222945  0.409182  1.000000  0.486862  0.632834  0.309212
# budget   0.309212  0.055665  0.486862  1.000000  0.750157  0.269510
# gross    0.261900  0.186392  0.632834  0.750157  1.000000  0.245235
# runtime  0.120811  0.399451  0.309212  0.269510  0.245235  1.000000

# %%
df.corr(numeric_only=True, method='kendall')
# Out:
#              year     score     votes    budget     gross   runtime
# year     1.000000  0.067652  0.331465  0.209304  0.216595  0.097184
# score    0.067652  1.000000  0.300115 -0.005194  0.090626  0.283611
# votes    0.331465  0.300115  1.000000  0.439902  0.560118  0.198240
# budget   0.209304 -0.005194  0.439902  1.000000  0.541956  0.176016
# gross    0.216595  0.090626  0.560118  0.541956  1.000000  0.176912
# runtime  0.097184  0.283611  0.198240  0.176016  0.176912  1.000000

# %%
df.corr(numeric_only=True, method='spearman')
# Out:
#              year     score     votes    budget     gross   runtime
# year     1.000000  0.099045  0.469829  0.291152  0.314681  0.142977
# score    0.099045  1.000000  0.428138 -0.007500  0.132569  0.399857
# votes    0.469829  0.428138  1.000000  0.604627  0.752265  0.290159
# budget   0.291152 -0.007500  0.604627  1.000000  0.716816  0.246748
# gross    0.314681  0.132569  0.752265  0.716816  1.000000  0.256783
# runtime  0.142977  0.399857  0.290159  0.246748  0.256783  1.000000

# %%
correlation_matrix = df.corr(numeric_only = True, method = 'pearson')

sns.heatmap(correlation_matrix, annot=True)

plt.title('Correlation Matrix for Numeric Features')

plt.xlabel('Movie Features')

plt.ylabel('Movie Features')

plt.show()

# %%
df_numerized = df.copy()

for col_name in df_numerized.columns:
    if(df_numerized[col_name].dtype == 'object'):
        df_numerized[col_name] = df_numerized[col_name].astype('category')
        df_numerized[col_name] = df_numerized[col_name].cat.codes

df_numerized
df.head()
# Out:
#                                              name rating      genre  year  \
# 0                                     The Shining      R      Drama  1980
# 1                                 The Blue Lagoon      R  Adventure  1980
# 2  Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# 3                                       Airplane!     PG     Comedy  1980
# 4                                      Caddyshack      R     Comedy  1980
#
#     released  score      votes         director                   writer  \
# 0  13-Jun-80    8.4   927000.0  Stanley Kubrick             Stephen King
# 1   2-Jul-80    5.8    65000.0   Randal Kleiser  Henry De Vere Stacpoole
# 2  20-Jun-80    8.7  1200000.0   Irvin Kershner           Leigh Brackett
# 3   2-Jul-80    7.7   221000.0     Jim Abrahams             Jim Abrahams
# 4  25-Jul-80    7.3   108000.0     Harold Ramis       Brian Doyle-Murray
#
#              star         country    budget      gross             company  \
# 0  Jack Nicholson  United Kingdom  19000000   46998772        Warner Bros.
# 1  Brooke Shields   United States   4500000   58853106   Columbia Pictures
# 2     Mark Hamill   United States  18000000  538375067           Lucasfilm
# 3     Robert Hays   United States   3500000   83453539  Paramount Pictures
# 4     Chevy Chase   United States   6000000   39846344      Orion Pictures
#
#    runtime  yearcorrect
# 0    146.0          NaN
# 1    104.0          NaN
# 2    124.0          NaN
# 3     88.0          NaN
# 4     98.0          NaN

# %%
correlation_matrix = df_numerized.corr(numeric_only = True, method = 'pearson')

sns.heatmap(correlation_matrix, annot=True)

plt.title('Correlation Matrix for Numeric and String Features')

plt.xlabel('Movie Features')

plt.ylabel('Movie Features')

plt.show()

# %%
correlation_mat = df_numerized.corr()

corr_pairs = correlation_mat.unstack()

corr_pairs
# Out:
# name      name        1.000000
#           rating     -0.008069
#           genre       0.016355
#           year        0.011453
#           released    0.008881
#           score       0.017097
#           votes       0.013088
#           director    0.009080
#           writer      0.009081
#           star        0.006472
#           country    -0.010737
#           budget      0.020548
#           gross       0.006989
#           company     0.009210
#           runtime     0.010392
# rating    name       -0.008069
#           rating      1.000000
#           genre       0.072423
#           year        0.008779
#           released    0.025053
#           score      -0.001314
#           votes       0.033225
#           director    0.019483
#           writer     -0.005921
#           star        0.013405
#           country     0.081244
#           budget     -0.081939
#           gross      -0.095450
#           company    -0.032943
#           runtime     0.062145
# genre     name        0.016355
#           rating      0.072423
#           genre       1.000000
#           year       -0.081261
#           released    0.006874
#           score       0.027965
#           votes      -0.145307
#           director   -0.015258
#           writer      0.006567
#           star       -0.005477
#           country    -0.037615
#           budget     -0.334021
#           gross      -0.234297
#           company    -0.071067
#           runtime    -0.052711
# year      name        0.011453
#           rating      0.008779
#           genre      -0.081261
#           year        1.000000
#           released   -0.007134
#           score       0.097995
#           votes       0.222945
#           director   -0.020795
#           writer     -0.008656
#           star       -0.027242
#           country    -0.070938
#           budget      0.309212
#           gross       0.261900
#           company    -0.010431
#           runtime     0.120811
# released  name        0.008881
#           rating      0.025053
#           genre       0.006874
#           year       -0.007134
#           released    1.000000
#           score       0.005767
#           votes      -0.011829
#           director   -0.005731
#           writer     -0.002145
#           star        0.006911
#           country    -0.012039
#           budget     -0.020107
#           gross      -0.010174
#           company    -0.008113
#           runtime    -0.015401
# score     name        0.017097
#           rating     -0.001314
#           genre       0.027965
#           year        0.097995
#           released    0.005767
#           score       1.000000
#           votes       0.409182
#           director    0.009559
#           writer      0.019416
#           star       -0.001609
#           country    -0.133348
#           budget      0.055665
#           gross       0.186392
#           company     0.001030
#           runtime     0.399451
# votes     name        0.013088
#           rating      0.033225
#           genre      -0.145307
#           year        0.222945
#           released   -0.011829
#           score       0.409182
#           votes       1.000000
#           director    0.000260
#           writer      0.000892
#           star       -0.019282
#           country     0.073625
#           budget      0.486862
#           gross       0.632834
#           company     0.133204
#           runtime     0.309212
# director  name        0.009080
#           rating      0.019483
#           genre      -0.015258
#           year       -0.020795
#           released   -0.005731
#           score       0.009559
#           votes       0.000260
#           director    1.000000
#           writer      0.299067
#           star        0.039234
#           country     0.017490
#           budget      0.004976
#           gross      -0.014916
#           company     0.004404
#           runtime     0.017624
# writer    name        0.009081
#           rating     -0.005921
#           genre       0.006567
#           year       -0.008656
#           released   -0.002145
#           score       0.019416
#           votes       0.000892
#           director    0.299067
#           writer      1.000000
#           star        0.027245
#           country     0.015343
#           budget     -0.025911
#           gross      -0.022997
#           company     0.005646
#           runtime    -0.003511
# star      name        0.006472
#           rating      0.013405
#           genre      -0.005477
#           year       -0.027242
#           released    0.006911
#           score      -0.001609
#           votes      -0.019282
#           director    0.039234
#           writer      0.027245
#           star        1.000000
#           country    -0.012998
#           budget     -0.019952
#           gross      -0.001129
#           company     0.012442
#           runtime     0.010174
# country   name       -0.010737
#           rating      0.081244
#           genre      -0.037615
#           year       -0.070938
#           released   -0.012039
#           score      -0.133348
#           votes       0.073625
#           director    0.017490
#           writer      0.015343
#           star       -0.012998
#           country     1.000000
#           budget      0.131720
#           gross       0.095325
#           company     0.095548
#           runtime    -0.078412
# budget    name        0.020548
#           rating     -0.081939
#           genre      -0.334021
#           year        0.309212
#           released   -0.020107
#           score       0.055665
#           votes       0.486862
#           director    0.004976
#           writer     -0.025911
#           star       -0.019952
#           country     0.131720
#           budget      1.000000
#           gross       0.750157
#           company     0.186474
#           runtime     0.269510
# gross     name        0.006989
#           rating     -0.095450
#           genre      -0.234297
#           year        0.261900
#           released   -0.010174
#           score       0.186392
#           votes       0.632834
#           director   -0.014916
#           writer     -0.022997
#           star       -0.001129
#           country     0.095325
#           budget      0.750157
#           gross       1.000000
#           company     0.156745
#           runtime     0.245235
# company   name        0.009210
#           rating     -0.032943
#           genre      -0.071067
#           year       -0.010431
#           released   -0.008113
#           score       0.001030
#           votes       0.133204
#           director    0.004404
#           writer      0.005646
#           star        0.012442
#           country     0.095548
#           budget      0.186474
#           gross       0.156745
#           company     1.000000
#           runtime     0.034402
# runtime   name        0.010392
#           rating      0.062145
#           genre      -0.052711
#           year        0.120811
#           released   -0.015401
#           score       0.399451
#           votes       0.309212
#           director    0.017624
#           writer     -0.003511
#           star        0.010174
#           country    -0.078412
#           budget      0.269510
#           gross       0.245235
#           company     0.034402
#           runtime     1.000000
# dtype: float64

# %%
sorted_pairs = corr_pairs.sort_values()

sorted_pairs
# Out:
# budget    genre      -0.334021
# genre     budget     -0.334021
#           gross      -0.234297
# gross     genre      -0.234297
# genre     votes      -0.145307
# votes     genre      -0.145307
# score     country    -0.133348
# country   score      -0.133348
# gross     rating     -0.095450
# rating    gross      -0.095450
# budget    rating     -0.081939
# rating    budget     -0.081939
# genre     year       -0.081261
# year      genre      -0.081261
# country   runtime    -0.078412
# runtime   country    -0.078412
# genre     company    -0.071067
# company   genre      -0.071067
# country   year       -0.070938
# year      country    -0.070938
# runtime   genre      -0.052711
# genre     runtime    -0.052711
# country   genre      -0.037615
# genre     country    -0.037615
# company   rating     -0.032943
# rating    company    -0.032943
# year      star       -0.027242
# star      year       -0.027242
# budget    writer     -0.025911
# writer    budget     -0.025911
# gross     writer     -0.022997
# writer    gross      -0.022997
# year      director   -0.020795
# director  year       -0.020795
# released  budget     -0.020107
# budget    released   -0.020107
# star      budget     -0.019952
# budget    star       -0.019952
# star      votes      -0.019282
# votes     star       -0.019282
# released  runtime    -0.015401
# runtime   released   -0.015401
# genre     director   -0.015258
# director  genre      -0.015258
#           gross      -0.014916
# gross     director   -0.014916
# country   star       -0.012998
# star      country    -0.012998
# country   released   -0.012039
# released  country    -0.012039
# votes     released   -0.011829
# released  votes      -0.011829
# name      country    -0.010737
# country   name       -0.010737
# year      company    -0.010431
# company   year       -0.010431
# released  gross      -0.010174
# gross     released   -0.010174
# writer    year       -0.008656
# year      writer     -0.008656
# company   released   -0.008113
# released  company    -0.008113
# rating    name       -0.008069
# name      rating     -0.008069
# year      released   -0.007134
# released  year       -0.007134
# rating    writer     -0.005921
# writer    rating     -0.005921
# director  released   -0.005731
# released  director   -0.005731
# star      genre      -0.005477
# genre     star       -0.005477
# writer    runtime    -0.003511
# runtime   writer     -0.003511
# released  writer     -0.002145
# writer    released   -0.002145
# star      score      -0.001609
# score     star       -0.001609
# rating    score      -0.001314
# score     rating     -0.001314
# gross     star       -0.001129
# star      gross      -0.001129
# votes     director    0.000260
# director  votes       0.000260
# writer    votes       0.000892
# votes     writer      0.000892
# company   score       0.001030
# score     company     0.001030
# director  company     0.004404
# company   director    0.004404
# budget    director    0.004976
# director  budget      0.004976
# writer    company     0.005646
# company   writer      0.005646
# released  score       0.005767
# score     released    0.005767
# star      name        0.006472
# name      star        0.006472
# genre     writer      0.006567
# writer    genre       0.006567
# released  genre       0.006874
# genre     released    0.006874
# star      released    0.006911
# released  star        0.006911
# gross     name        0.006989
# name      gross       0.006989
# year      rating      0.008779
# rating    year        0.008779
# released  name        0.008881
# name      released    0.008881
# director  name        0.009080
# name      director    0.009080
#           writer      0.009081
# writer    name        0.009081
# company   name        0.009210
# name      company     0.009210
# score     director    0.009559
# director  score       0.009559
# star      runtime     0.010174
# runtime   star        0.010174
#           name        0.010392
# name      runtime     0.010392
#           year        0.011453
# year      name        0.011453
# company   star        0.012442
# star      company     0.012442
# votes     name        0.013088
# name      votes       0.013088
# rating    star        0.013405
# star      rating      0.013405
# country   writer      0.015343
# writer    country     0.015343
# name      genre       0.016355
# genre     name        0.016355
# score     name        0.017097
# name      score       0.017097
# country   director    0.017490
# director  country     0.017490
# runtime   director    0.017624
# director  runtime     0.017624
# writer    score       0.019416
# score     writer      0.019416
# director  rating      0.019483
# rating    director    0.019483
# name      budget      0.020548
# budget    name        0.020548
# rating    released    0.025053
# released  rating      0.025053
# star      writer      0.027245
# writer    star        0.027245
# score     genre       0.027965
# genre     score       0.027965
# votes     rating      0.033225
# rating    votes       0.033225
# runtime   company     0.034402
# company   runtime     0.034402
# star      director    0.039234
# director  star        0.039234
# score     budget      0.055665
# budget    score       0.055665
# runtime   rating      0.062145
# rating    runtime     0.062145
#           genre       0.072423
# genre     rating      0.072423
# country   votes       0.073625
# votes     country     0.073625
# rating    country     0.081244
# country   rating      0.081244
# gross     country     0.095325
# country   gross       0.095325
#           company     0.095548
# company   country     0.095548
# score     year        0.097995
# year      score       0.097995
#           runtime     0.120811
# runtime   year        0.120811
# country   budget      0.131720
# budget    country     0.131720
# votes     company     0.133204
# company   votes       0.133204
#           gross       0.156745
# gross     company     0.156745
#           score       0.186392
# score     gross       0.186392
# budget    company     0.186474
# company   budget      0.186474
# year      votes       0.222945
# votes     year        0.222945
# gross     runtime     0.245235
# runtime   gross       0.245235
# year      gross       0.261900
# gross     year        0.261900
# budget    runtime     0.269510
# runtime   budget      0.269510
# director  writer      0.299067
# writer    director    0.299067
# budget    year        0.309212
# year      budget      0.309212
# votes     runtime     0.309212
# runtime   votes       0.309212
# score     runtime     0.399451
# runtime   score       0.399451
# votes     score       0.409182
# score     votes       0.409182
# votes     budget      0.486862
# budget    votes       0.486862
# gross     votes       0.632834
# votes     gross       0.632834
# budget    gross       0.750157
# gross     budget      0.750157
# name      name        1.000000
# director  director    1.000000
# gross     gross       1.000000
# budget    budget      1.000000
# country   country     1.000000
# star      star        1.000000
# writer    writer      1.000000
# votes     votes       1.000000
# score     score       1.000000
# released  released    1.000000
# year      year        1.000000
# genre     genre       1.000000
# rating    rating      1.000000
# company   company     1.000000
# runtime   runtime     1.000000
# dtype: float64

# %%
high_corr = sorted_pairs[(sorted_pairs)>0.5]
high_corr
# Out:
# gross     votes       0.632834
# votes     gross       0.632834
# budget    gross       0.750157
# gross     budget      0.750157
# name      name        1.000000
# director  director    1.000000
# gross     gross       1.000000
# budget    budget      1.000000
# country   country     1.000000
# star      star        1.000000
# writer    writer      1.000000
# votes     votes       1.000000
# score     score       1.000000
# released  released    1.000000
# year      year        1.000000
# genre     genre       1.000000
# rating    rating      1.000000
# company   company     1.000000
# runtime   runtime     1.000000
# dtype: float64
